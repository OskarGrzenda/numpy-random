# %% [markdown]
# # The Numpy Random Package
#
# [Official Documentation] (https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

# %%
# Change default style sheet.
plt.style.use('fivethirtyeight')

# Change the default figure size.
plt.rcParams['figure.figsize'] = [12, 6]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at first ten items.
s[:10]
# Out:
# array([-0.01469788, -0.12562178,  0.08596705,  0.14355393, -0.07338486,
#         0.08254548,  0.2219818 ,  0.12516165,  0.11142127, -0.09245198])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0009832326509767713

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0015732762876207174

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins-mu)**2/(2*sigma**2))
plt.plot(bins, f,linewidth=2)
plt.show()

# %%
# References

- https://www.datacamp.com/community/tutorials/numpy-random
# Out:
#   File "<ipython-input-8-456c70f3de8b>", line 3
#     - https://www.datacamp.com/community/tutorials/numpy-random
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ***
# End
